# %% [markdown]
# # Capstone

# %% [markdown]
# ## Part 1 - Analytics on Raw Data

# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
all_files = glob.glob("Raw_Data/*.csv")
df = pd.concat((pd.read_csv(f) for f in all_files))

# %% [markdown]
# **Basic checks have been done on the data to make sure everything is generally ok; nothing has been missed**

# %%
# df.head()
# df[['YEAR', 'MONTH']].drop_duplicates().sort_values(['YEAR', 'MONTH'])

# %% [markdown]
# **We will also do some data cleanup in this section:**
# * We will filter to only the columns that are of interest to us for this Capstone project
# * Only Ancorage origin airport will be looked at
# * The actual carrier descriptions will be shown
# * Cancellation code descriptions will be shown
# * Delays over 60 minutes will be looked at - a respective column will be added to the data

# %%
# Columns that will be kept for analysis
columns_to_keep =  [
    "YEAR",
    "QUARTER",
    "MONTH",
    "DAY_OF_MONTH",
    "DAY_OF_WEEK",
    "OP_UNIQUE_CARRIER",
    "TAIL_NUM",
    "OP_CARRIER_FL_NUM",
    "ORIGIN",
    "DEST",
    "CRS_DEP_TIME",
    "CRS_ARR_TIME",
    "CANCELLED",
    "CANCELLATION_CODE",
    "DIVERTED",
    "AIR_TIME",
    "DISTANCE",
    "CARRIER_DELAY",
    "WEATHER_DELAY",
    "NAS_DELAY",
    "SECURITY_DELAY",
    "LATE_AIRCRAFT_DELAY" ]

# Delay threshold of 60 mins
delay_threshold = 60

# Filtering & Replacing
df1 = df.copy()
df1 = df1[columns_to_keep]
df1 = df1[df1['ORIGIN'] == 'ANC']
df1['OP_UNIQUE_CARRIER'] = df1['OP_UNIQUE_CARRIER'].replace(['AS', 'DL', 'UA', 'AA'], ['Alaska Airlines', 'Delta', 'United', 'American Airlines'])
df1['CANCELLATION_CODE'] = df1['CANCELLATION_CODE'].replace(['A', 'B', 'C'], ['Carrier', 'Weather', 'National Air System'])

# Create totals & classification of the delay
df1['TOTAL_DELAY'] = df1["CARRIER_DELAY"] + df1["WEATHER_DELAY"] + df1["NAS_DELAY"] + df1["SECURITY_DELAY"] + df1["LATE_AIRCRAFT_DELAY"]
df1['CRITICAL_DELAY'] = np.where(
    (df1['TOTAL_DELAY'] >= delay_threshold) | 
    (df1['CANCELLED'] == 1) | 
    (df1['DIVERTED'] == 1),
    1,  # if true
    0   # else
)

# Tidy up delay columns
df1["CARRIER_DELAY"] = df1["CARRIER_DELAY"].fillna(0)
df1["WEATHER_DELAY"] = df1["WEATHER_DELAY"].fillna(0)
df1["NAS_DELAY"] = df1["NAS_DELAY"].fillna(0)
df1["SECURITY_DELAY"] = df1["SECURITY_DELAY"].fillna(0)
df1["LATE_AIRCRAFT_DELAY"] = df1["LATE_AIRCRAFT_DELAY"].fillna(0)
df1['TOTAL_DELAY'] = df1['TOTAL_DELAY'].fillna(0)

# %%
#df1['OP_UNIQUE_CARRIER'].value_counts()
#df1['CANCELLATION_CODE'].value_counts()
#df1['CANCELLED'].value_counts()
#df1['DIVERTED'].value_counts()
# df1['CRITICAL_DELAY'].value_counts(normalize = True)

# %%
# 1 - Total flights & total flights delayed by airline
# 2 - Averages of total delay by airline, critical vs non critical delays
# 3 - Normalised proportion of flights affected by critical delays
# 4 - Average delay breakdown reason for critical delays

airlines = df1['OP_UNIQUE_CARRIER'].unique().tolist()

# 1
total_flights = df1.groupby('OP_UNIQUE_CARRIER')['YEAR'].count()
total_flights_delayed = df1[df1['CRITICAL_DELAY'] == 1].groupby('OP_UNIQUE_CARRIER')['YEAR'].count()

# 2
avg_delays_non_crit_delayed = df1[df1['CRITICAL_DELAY'] != 1].groupby('OP_UNIQUE_CARRIER')['TOTAL_DELAY'].mean().tolist()
avg_delays_crit_delayed = df1[df1['CRITICAL_DELAY'] == 1].groupby('OP_UNIQUE_CARRIER')['TOTAL_DELAY'].mean().tolist()

# 3
critical_delay_fraction = df1.groupby('OP_UNIQUE_CARRIER')['CRITICAL_DELAY'].mean().tolist()
critical_delay_fraction = [x * 100 for x in critical_delay_fraction]

# 4

# %%
x = np.arange(len(airlines))  # positions on x-axis
width = 0.35  # width of the bars

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

ax = axes[0, 0]
bars1 = ax.bar(x - width/2, total_flights, width, label='All')
bars2 = ax.bar(x + width/2, total_flights_delayed, width, label='Crit. Delayed')
for bar in bars1:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, height + 0.5, f'{height}', ha='center', va='bottom', fontsize=9)
for bar in bars2:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, height + 0.5, f'{height}', ha='center', va='bottom', fontsize=9)
ax.set_ylabel('Number of Flights')
ax.set_title('Total flights by Airline')
ax.set_xticks(x)
ax.set_xticklabels(airlines, rotation=45, ha='right')
ax.set_ylim([0, 30000])
ax.legend()



ax = axes[0, 1]
bars1 = ax.bar(x - width/2, avg_delays_non_crit_delayed, label='Non Crit. Delayed')
bars2 = ax.bar(x + width/2, avg_delays_crit_delayed, width, label='Crit. Delayed')
for bar in bars1:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{round(height)}', ha='center', va='bottom', fontsize=9)
for bar in bars2:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{round(height)}', ha='center', va='bottom', fontsize=9)
ax.set_ylabel('Average Delay (minutes)')
ax.set_title('Average Delays by Airline')
ax.set_xticks(x)
ax.set_xticklabels(airlines, rotation=45, ha='right')
ax.set_ylim([0, 300])
ax.legend()



ax = axes[1, 0]
bars1 = ax.bar(x - width/2, critical_delay_fraction, width)
for bar in bars1:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.2f}', ha='center',  va='bottom', fontsize=9 )

ax.set_ylabel('Fraction of Critical Delays')
ax.set_title('Critical Delay Fraction by Airline')
ax.set_xticks(x)
ax.set_xticklabels(airlines, rotation=45, ha='right')
ax.set_ylim([0, 12])



ax = axes[1, 1]


plt.tight_layout()
plt.show()

# %%
avg_critical_delay_carrier = df1[df1['CRITICAL_DELAY'] == 1].groupby('OP_UNIQUE_CARRIER')["CARRIER_DELAY"].mean().to_numpy().tolist()
avg_critical_delay_weather = df1[df1['CRITICAL_DELAY'] == 1].groupby('OP_UNIQUE_CARRIER')["WEATHER_DELAY"].mean().to_numpy().tolist()
avg_critical_delay_nas = df1[df1['CRITICAL_DELAY'] == 1].groupby('OP_UNIQUE_CARRIER')["NAS_DELAY"].mean().to_numpy().tolist()
avg_critical_delay_security = df1[df1['CRITICAL_DELAY'] == 1].groupby('OP_UNIQUE_CARRIER')["SECURITY_DELAY"].mean().to_numpy().tolist()
avg_critical_delay_aircraft = df1[df1['CRITICAL_DELAY'] == 1].groupby('OP_UNIQUE_CARRIER')["LATE_AIRCRAFT_DELAY"].mean().to_numpy().tolist()

# %%
delay_types = ['Carrier', 'Weather', 'NAS', 'Security', 'Late Aircraft']
x = np.arange(len(delay_types))
width = 0.15

data = np.array([
    avg_critical_delay_carrier,
    avg_critical_delay_weather,
    avg_critical_delay_nas,
    avg_critical_delay_security,
    avg_critical_delay_aircraft
]).T

fig, ax = plt.subplots(figsize=(12,6), layout='constrained')

# Plot bars for each airline
for i, airline in enumerate(airlines):
    ax.bar(x + (i - (len(airlines)-1)/2)*width, data[i], width, label=airline)

# Add value labels above bars
for i, airline in enumerate(airlines):
    for j, value in enumerate(data[i]):
        ax.text(
            x[j] + (i - (len(airlines)-1)/2)*width, 
            value + 2,  # slightly above the bar
            f'{round(value)}', 
            ha='center', 
            va='bottom', 
            fontsize=9
        )

ax.set_ylabel('Average Delay (minutes)')
ax.set_title('Average Critical Delay by Type and Airline')
ax.set_xticks(x)
ax.set_xticklabels(delay_types)
ax.set_ylim([0, max(data.flatten())*1.2])  # auto headroom for labels
ax.legend(title='Airline')  # added parentheses

plt.show()
